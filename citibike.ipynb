# %%
# Dependencies
import pandas as pd

# %%
# List of file names to be combined 
files15 = ['data/201501.csv', 'data/201502.csv', 'data/201503.csv', 'data/201504.csv', 'data/201505.csv', 'data/201506.csv', 'data/201507.csv', 'data/201508.csv', 'data/201509.csv', 'data/201510.csv', 'data/201511.csv', 'data/201512.csv']

# Create an empty list to store each dataframe
df15_list = []

# Loop through each file in the list
for x in files15:
    # Read the file into a dataframe
    df15 = pd.read_csv(x)

    # Append the dataframe to the list
    df15_list.append(df15)

# Concatenate all dataframes in the list into one dataframe
df15 = pd.concat(df15_list)

# Show dataframe
df15
# Out:
#         tripduration            starttime             stoptime  \
# 0               1346        1/1/2015 0:01        1/1/2015 0:24
# 1                363        1/1/2015 0:02        1/1/2015 0:08
# 2                346        1/1/2015 0:04        1/1/2015 0:10
# 3                182        1/1/2015 0:04        1/1/2015 0:07
# 4                969        1/1/2015 0:05        1/1/2015 0:21
# ...              ...                  ...                  ...
# 804120           509  12/31/2015 16:50:17  12/31/2015 16:58:46
# 804121           591  12/31/2015 17:17:52  12/31/2015 17:27:43
# 804122           197  12/31/2015 17:56:22  12/31/2015 17:59:39
# 804123           372  12/31/2015 21:20:38  12/31/2015 21:26:50
# 804124           395  12/31/2015 21:49:19  12/31/2015 21:55:55
#
#         start station id          start station name  start station latitude  \
# 0                    455             1 Ave & E 44 St               40.750020
# ...

# %%
# Get the number of null values in each column 
null_counts = df15.isna().sum()

# Show the number of null values
null_counts
# Out:
# tripduration                     0
# starttime                        0
# stoptime                         0
# start station id                 0
# start station name               0
# start station latitude           0
# start station longitude          0
# end station id                   0
# end station name                 0
# end station latitude             0
# end station longitude            0
# bikeid                           0
# usertype                         0
# birth year                 1311378
# gender                           0
# dtype: int64

# %%
# Drop rows containing null values
df15.dropna(inplace=True)

# Check to make sure all nulls were dropped
null_counts = df15.isna().sum()
null_counts
# Out:
# tripduration               0
# starttime                  0
# stoptime                   0
# start station id           0
# start station name         0
# start station latitude     0
# start station longitude    0
# end station id             0
# end station name           0
# end station latitude       0
# end station longitude      0
# bikeid                     0
# usertype                   0
# birth year                 0
# gender                     0
# dtype: int64

# %%
# List of file names to be combined 
files16 = ['data/201601.csv', 'data/201602.csv', 'data/201603.csv', 'data/201604.csv', 'data/201605.csv', 'data/201606.csv', 'data/201607.csv', 'data/201608.csv', 'data/201609.csv', 'data/201610.csv', 'data/201611.csv', 'data/201612.csv']

# Create an empty list to store each dataframe
df16_list = []

# list of file names to be renamed
rename_files = ['data/201610.csv', 'data/201611.csv', 'data/201612.csv']

# Loop through each file in the list
for y in files16:
    # Read the file into a dataframe
    df16 = pd.read_csv(y)

    # Check if the file name is in the list of files to be renamed
    if y in rename_files:
        # Specify the new column names
        new_columns = {'Trip Duration': 'tripduration','Start Time': 'starttime','Stop Time': 'stoptime','Start Station ID':'start station id','Start Station Name':'start station name','Start Station Latitude': 'start station latitude','Start Station Longitude': 'start station longitude','End Station ID': 'end station id','End Station Name': 'end station name','End Station Latitude': 'end station latitude','End Station Longitude': 'end station longitude','Bike ID': 'bikeid','User Type': 'usertype','Birth Year':'birth year','Gender': 'gender'}

        # Change the column names
        df16.rename(columns=new_columns, inplace=True)



    # Append the dataframe to the list
    df16_list.append(df16)

# Concatenate all dataframes in the list into one dataframe
df16 = pd.concat(df16_list)

# Show dataframe
df16
# Out:
#         tripduration            starttime             stoptime  \
# 0                923    1/1/2016 00:00:41    1/1/2016 00:16:04
# 1                379    1/1/2016 00:00:45    1/1/2016 00:07:04
# 2                589    1/1/2016 00:00:48    1/1/2016 00:10:37
# 3                889    1/1/2016 00:01:06    1/1/2016 00:15:56
# 4               1480    1/1/2016 00:01:12    1/1/2016 00:25:52
# ...              ...                  ...                  ...
# 812187           441  2016-12-31 23:56:15  2017-01-01 00:03:36
# 812188          1026  2016-12-31 23:56:19  2017-01-01 00:13:26
# 812189          1747  2016-12-31 23:56:35  2017-01-01 00:25:43
# 812190           951  2016-12-31 23:59:31  2017-01-01 00:15:23
# 812191          1322  2016-12-31 23:59:56  2017-01-01 00:21:58
#
#         start station id                 start station name  \
# 0                    268              Howard St & Centre St
# 1                    476                    E 31 St & 3 Ave
# ...

# %%
# Get the number of null values in each column 
null_counts = df16.isna().sum()

# Show the number of null values
null_counts
# Out:
# tripduration                     0
# starttime                        0
# stoptime                         0
# start station id                 0
# start station name               0
# start station latitude           0
# start station longitude          0
# end station id                   0
# end station name                 0
# end station latitude             0
# end station longitude            0
# bikeid                           0
# usertype                     35871
# birth year                 1586863
# gender                           0
# dtype: int64

# %%
# Drop rows containing null values
df16.dropna(inplace=True)

# Check to make sure all nulls were dropped
null_counts = df16.isna().sum()
null_counts
# Out:
# tripduration               0
# starttime                  0
# stoptime                   0
# start station id           0
# start station name         0
# start station latitude     0
# start station longitude    0
# end station id             0
# end station name           0
# end station latitude       0
# end station longitude      0
# bikeid                     0
# usertype                   0
# birth year                 0
# gender                     0
# dtype: int64

# %%
# List of file names to be combined 
files17 = ['data/201701.csv', 'data/201702.csv', 'data/201703.csv', 'data/201704.csv', 'data/201705.csv', 'data/201706.csv', 'data/201707.csv', 'data/201708.csv', 'data/201709.csv', 'data/201710.csv', 'data/201711.csv', 'data/201712.csv']

# Create an empty list to store each dataframe
df17_list = []

# list of file names to be renamed
edit_files = ['data/201701.csv', 'data/201702.csv', 'data/201703.csv']

# Loop through each file in the list
for z in files17:
    # Read the file into a dataframe
    df17 = pd.read_csv(z)

    # Check if the file name is in the list of files to be renamed
    if z in edit_files:
        # Specify the new column names
        new_columns1 = {'Trip Duration': 'tripduration','Start Time': 'starttime','Stop Time': 'stoptime','Start Station ID':'start station id','Start Station Name':'start station name','Start Station Latitude': 'start station latitude','Start Station Longitude': 'start station longitude','End Station ID': 'end station id','End Station Name': 'end station name','End Station Latitude': 'end station latitude','End Station Longitude': 'end station longitude','Bike ID': 'bikeid','User Type': 'usertype','Birth Year':'birth year','Gender': 'gender'}

        # Change the column names
        df17.rename(columns=new_columns1, inplace=True)

    # Append the dataframe to the list
    df17_list.append(df17)

# Concatenate all dataframes in the list into one dataframe
df17 = pd.concat(df17_list)

# Show dataframe
df17
# Out:
#         tripduration            starttime             stoptime  \
# 0                680  2017-01-01 00:00:21  2017-01-01 00:11:41
# 1               1282  2017-01-01 00:00:45  2017-01-01 00:22:08
# 2                648  2017-01-01 00:00:57  2017-01-01 00:11:46
# 3                631  2017-01-01 00:01:10  2017-01-01 00:11:42
# 4                621  2017-01-01 00:01:25  2017-01-01 00:11:47
# ...              ...                  ...                  ...
# 889962           397  2017-12-31 23:54:22  2018-01-01 00:01:00
# 889963           332  2017-12-31 23:54:44  2018-01-01 00:00:16
# 889964           565  2017-12-31 23:56:07  2018-01-01 00:05:33
# 889965          1659  2017-12-31 23:57:16  2018-01-01 00:24:56
# 889966          1279  2017-12-31 23:58:56  2018-01-01 00:20:16
#
#         start station id           start station name  start station latitude  \
# 0                   3226  W 82 St & Central Park West               40.782750
# ...

# %%
# Get the number of null values in each column 
null_counts = df17.isna().sum()

# Show the number of null values
null_counts
# Out:
# tripduration                     0
# starttime                        0
# stoptime                         0
# start station id                 0
# start station name               0
# start station latitude           0
# start station longitude          0
# end station id                   0
# end station name                 0
# end station latitude             0
# end station longitude            0
# bikeid                           0
# usertype                     15909
# birth year                 1630335
# gender                           0
# dtype: int64

# %%
# Drop rows containing null values
df17.dropna(inplace=True)

# Check to make sure all nulls were dropped
null_counts = df17.isna().sum()
null_counts
# Out:
# tripduration               0
# starttime                  0
# stoptime                   0
# start station id           0
# start station name         0
# start station latitude     0
# start station longitude    0
# end station id             0
# end station name           0
# end station latitude       0
# end station longitude      0
# bikeid                     0
# usertype                   0
# birth year                 0
# gender                     0
# dtype: int64

# %%
# List of file names to be combined 
files18 = ['data/201801.csv', 'data/201802.csv', 'data/201803.csv', 'data/201804.csv', 'data/201805.csv', 'data/201806.csv', 'data/201807.csv', 'data/201808.csv', 'data/201809.csv', 'data/201810.csv', 'data/201811.csv', 'data/201812.csv']

# Create an empty list to store each dataframe
df18_list = []

# Loop through each file in the list
for file in files18:
    # Read the file into a dataframe
    df18 = pd.read_csv(file)

    # Append the dataframe to the list
    df18_list.append(df18)

# Concatenate all dataframes in the list into one dataframe
df18 = pd.concat(df18_list)

# Show dataframe
df18
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               932  2018-01-01 02:06:17.5410  2018-01-01 02:21:50.0270
# 1               550  2018-01-01 12:06:18.0390  2018-01-01 12:15:28.4430
# 2               510  2018-01-01 12:06:56.9780  2018-01-01 12:15:27.8100
# 3               354  2018-01-01 14:53:10.1860  2018-01-01 14:59:05.0960
# 4               250  2018-01-01 17:34:30.1920  2018-01-01 17:38:40.9840
# ...             ...                       ...                       ...
# 20200          1081  2018-12-22 11:51:46.0600  2018-12-22 12:09:47.4730
# 20201           344  2018-12-25 21:40:09.8660  2018-12-25 21:45:54.2670
# 20202          1233  2018-12-29 12:55:45.9690  2018-12-29 13:16:19.5960
# 20203          1057  2018-12-30 15:32:09.3320  2018-12-30 15:49:46.3510
# 20204           301  2018-12-31 16:34:11.9340  2018-12-31 16:39:13.8340
#
#        start station id start station name  start station latitude  \
# ...

# %%
# Get the number of null values in each column 
null_counts = df18.isna().sum()

# Show the number of null values
null_counts
# Out:
# tripduration               0
# starttime                  0
# stoptime                   0
# start station id           0
# start station name         0
# start station latitude     0
# start station longitude    0
# end station id             0
# end station name           0
# end station latitude       0
# end station longitude      0
# bikeid                     0
# usertype                   0
# birth year                 0
# gender                     0
# dtype: int64

# %%
# List of file names to be combined 
files19 = ['data/201901.csv', 'data/201902.csv', 'data/201903.csv', 'data/201904.csv', 'data/201905.csv', 'data/201906.csv', 'data/201907.csv', 'data/201908.csv', 'data/201909.csv', 'data/201910.csv', 'data/201911.csv', 'data/201912.csv']

# Create an empty list to store each dataframe
df19_list = []

# Loop through each file in the list
for f in files19:
    # Read the file into a dataframe
    df19 = pd.read_csv(f)

    # Append the dataframe to the list
    df19_list.append(df19)

# Concatenate all dataframes in the list into one DataFrame
df19 = pd.concat(df19_list)

# Show dataframe
df19
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               201  2019-01-01 03:09:09.7110  2019-01-01 03:12:30.8790
# 1               505  2019-01-01 05:18:00.1060  2019-01-01 05:26:25.9050
# 2               756  2019-01-01 10:36:33.3400  2019-01-01 10:49:10.2600
# 3              1575  2019-01-01 12:43:38.6430  2019-01-01 13:09:54.5280
# 4              1566  2019-01-01 12:43:39.6010  2019-01-01 13:09:46.5100
# ...             ...                       ...                       ...
# 19723           283  2019-12-31 23:12:18.5480  2019-12-31 23:17:01.8740
# 19724           267  2019-12-31 23:19:03.5840  2019-12-31 23:23:30.6640
# 19725           379  2019-12-31 23:19:06.5830  2019-12-31 23:25:25.7970
# 19726           188  2019-12-31 23:24:00.2630  2019-12-31 23:27:09.0400
# 19727           326  2019-12-31 23:45:20.9780  2019-12-31 23:50:47.7490
#
#        start station id start station name  start station latitude  \
# ...

# %%
# Get the number of null values in each column 
null_counts = df19.isna().sum()

# Show the number of null values
null_counts
# Out:
# tripduration               0
# starttime                  0
# stoptime                   0
# start station id           0
# start station name         0
# start station latitude     0
# start station longitude    0
# end station id             0
# end station name           0
# end station latitude       0
# end station longitude      0
# bikeid                     0
# usertype                   0
# birth year                 0
# gender                     0
# dtype: int64

# %%
# List of file names to be combined 
files20 = ['data/202001.csv', 'data/202002.csv', 'data/202003.csv', 'data/202004.csv', 'data/202005.csv', 'data/202006.csv', 'data/202007.csv', 'data/202008.csv', 'data/202009.csv', 'data/202010.csv', 'data/202011.csv', 'data/202012.csv']

# Create an empty list to store each dataframe
df20_list = []

# Loop through each file in the list
for i in files20:
    # Read the file into a dataframe
    df20 = pd.read_csv(i)

    # Append the dataframe to the list
    df20_list.append(df20)

# Concatenate all dataframes in the list into one DataFrame
df20 = pd.concat(df20_list)

# Show dataframe
df20
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               226  2020-01-01 00:04:50.1920  2020-01-01 00:08:37.0370
# 1               377  2020-01-01 00:16:01.6700  2020-01-01 00:22:19.0800
# 2               288  2020-01-01 00:17:33.8770  2020-01-01 00:22:22.4420
# 3               435  2020-01-01 00:32:05.9020  2020-01-01 00:39:21.0660
# 4               231  2020-01-01 00:46:19.6780  2020-01-01 00:50:11.3440
# ...             ...                       ...                       ...
# 11689          1750  2020-12-31 23:07:44.0030  2020-12-31 23:36:54.4710
# 11690          1519  2020-12-31 23:18:00.2630  2020-12-31 23:43:19.8590
# 11691          1761  2020-12-31 23:31:09.4620  2021-01-01 00:00:31.3290
# 11692           637  2020-12-31 23:35:45.4640  2020-12-31 23:46:22.7300
# 11693          1607  2020-12-31 23:48:34.5750  2021-01-01 00:15:22.3090
#
#        start station id start station name  start station latitude  \
# ...

# %%
# Get the number of null values in each column 
null_counts = df20.isna().sum()

# Show the number of null values
null_counts
# Out:
# tripduration               0
# starttime                  0
# stoptime                   0
# start station id           0
# start station name         0
# start station latitude     0
# start station longitude    0
# end station id             0
# end station name           0
# end station latitude       0
# end station longitude      0
# bikeid                     0
# usertype                   0
# birth year                 0
# gender                     0
# dtype: int64

# %%
# Concatenate all dataframes for all the years into one
combined_df = pd.concat([df15, df16, df17, df18, df19, df20], axis=0)

# Display the results
combined_df
# Out:
#        tripduration                 starttime                  stoptime  \
# 0              1346             1/1/2015 0:01             1/1/2015 0:24
# 1               363             1/1/2015 0:02             1/1/2015 0:08
# 2               346             1/1/2015 0:04             1/1/2015 0:10
# 3               182             1/1/2015 0:04             1/1/2015 0:07
# 4               969             1/1/2015 0:05             1/1/2015 0:21
# ...             ...                       ...                       ...
# 11689          1750  2020-12-31 23:07:44.0030  2020-12-31 23:36:54.4710
# 11690          1519  2020-12-31 23:18:00.2630  2020-12-31 23:43:19.8590
# 11691          1761  2020-12-31 23:31:09.4620  2021-01-01 00:00:31.3290
# 11692           637  2020-12-31 23:35:45.4640  2020-12-31 23:46:22.7300
# 11693          1607  2020-12-31 23:48:34.5750  2021-01-01 00:15:22.3090
#
#        start station id       start station name  start station latitude  \
# ...

# %%
# Dictionary mapping values in the 'gender' column to new values
mapping = {0: 'Unknown', 1: 'Male', 2: 'Female'}

# Use the 'map' method to change the values in the 'gender' column
combined_df['gender'] = combined_df['gender'].map(mapping)

# Show DataFrame
combined_df
# Out:
#        tripduration                 starttime                  stoptime  \
# 0              1346             1/1/2015 0:01             1/1/2015 0:24
# 1               363             1/1/2015 0:02             1/1/2015 0:08
# 2               346             1/1/2015 0:04             1/1/2015 0:10
# 3               182             1/1/2015 0:04             1/1/2015 0:07
# 4               969             1/1/2015 0:05             1/1/2015 0:21
# ...             ...                       ...                       ...
# 11689          1750  2020-12-31 23:07:44.0030  2020-12-31 23:36:54.4710
# 11690          1519  2020-12-31 23:18:00.2630  2020-12-31 23:43:19.8590
# 11691          1761  2020-12-31 23:31:09.4620  2021-01-01 00:00:31.3290
# 11692           637  2020-12-31 23:35:45.4640  2020-12-31 23:46:22.7300
# 11693          1607  2020-12-31 23:48:34.5750  2021-01-01 00:15:22.3090
#
#        start station id       start station name  start station latitude  \
# ...

# %%
# Save the dataframe to a CSV file
combined_df.to_csv('data/citibike.csv', index=False)
